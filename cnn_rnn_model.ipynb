# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (GlobalAveragePooling2D, Dropout, Dense,
                                    SimpleRNN, Reshape, BatchNormalization, Input,
                                     )
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
import matplotlib.pyplot as plt

# %%
tf.random.set_seed(42)
np.random.seed(42)

# %%
data_train_path = 'Dataset/Train'
data_val_path = 'Dataset/Validation'
data_test_path = 'Dataset/Test'

# %%
img_width = 224
img_height = 224
batch_size = 32

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    data_train_path,
    validation_split=0.5,
    subset="training",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size,
    label_mode='binary'
)

# Load validation data
val_ds = tf.keras.utils.image_dataset_from_directory(
    data_val_path,
    image_size=(img_height, img_width),
    batch_size=batch_size,
    shuffle=False,
    label_mode='binary'
)

# Load test data
test_ds = tf.keras.utils.image_dataset_from_directory(
    data_test_path,
    image_size=(img_height, img_width),
    shuffle=False,
    batch_size=batch_size,
    label_mode='binary'
)
# Out:
# Found 140002 files belonging to 2 classes.
# Using 70001 files for training.
# Found 39428 files belonging to 2 classes.
# Found 10905 files belonging to 2 classes.

# %%
normalization_layer = layers.Rescaling(1./255)
train_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
val_ds = val_ds.map(lambda x, y: (normalization_layer(x), y))
test_ds = test_ds.map(lambda x, y: (normalization_layer(x), y))

# Data augmentation
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
])

# %%
def build_improved_model(input_shape=(img_height, img_width, 3)):
    inputs = Input(shape=input_shape)
    x = data_augmentation(inputs)
    
    # Base model (MobileNetV2)
    base_model = MobileNetV2(
        weights='imagenet', 
        include_top=False, 
        input_shape=input_shape
    )
    base_model.trainable = False
    
    x = base_model(x)
    x = GlobalAveragePooling2D()(x)
    x = Reshape((1, -1))(x)
    
    # Improved RNN layers
    x = SimpleRNN(128, return_sequences=True)(x)
    x = Dropout(0.4)(x)
    x = SimpleRNN(64)(x)
    x = Dropout(0.4)(x)
    
    # Enhanced classifier
    x = Dense(128, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    outputs = Dense(1, activation='sigmoid')(x)
    
    return Model(inputs, outputs)

# %%
model = build_improved_model()
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='binary_crossentropy',
    metrics=['accuracy', tf.keras.metrics.AUC(name='auc')]
)

# %%
callbacks = [
    ReduceLROnPlateau(monitor='val_auc', factor=0.5, patience=3, min_lr=1e-6, mode='max'),
    ModelCheckpoint(
        filepath='best_model.keras',
        save_best_only=True,
        monitor='val_auc',
        mode='max'
    )
]

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=50,
    callbacks=callbacks
)
# Out:
# Epoch 1/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1809s 820ms/step - accuracy: 0.6107 - auc: 0.6533 - loss: 0.8280 - val_accuracy: 0.7486 - val_auc: 0.8370 - val_loss: 0.5165 - learning_rate: 1.0000e-04
# Epoch 2/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1933s 883ms/step - accuracy: 0.7075 - auc: 0.7775 - loss: 0.6020 - val_accuracy: 0.7593 - val_auc: 0.8506 - val_loss: 0.4990 - learning_rate: 1.0000e-04
# Epoch 3/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1330s 608ms/step - accuracy: 0.7401 - auc: 0.8147 - loss: 0.5337 - val_accuracy: 0.7569 - val_auc: 0.8560 - val_loss: 0.5063 - learning_rate: 1.0000e-04
# Epoch 4/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1344s 614ms/step - accuracy: 0.7606 - auc: 0.8373 - loss: 0.4981 - val_accuracy: 0.7585 - val_auc: 0.8620 - val_loss: 0.5040 - learning_rate: 1.0000e-04
# Epoch 5/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1544s 679ms/step - accuracy: 0.7647 - auc: 0.8448 - loss: 0.4850 - val_accuracy: 0.7574 - val_auc: 0.8651 - val_loss: 0.4852 - learning_rate: 1.0000e-04
# Epoch 6/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1395s 620ms/step - accuracy: 0.7725 - auc: 0.8543 - loss: 0.4716 - val_accuracy: 0.7494 - val_auc: 0.8673 - val_loss: 0.5173 - learning_rate: 1.0000e-04
# Epoch 7/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1369s 626ms/step - accuracy: 0.7760 - auc: 0.8589 - loss: 0.4649 - val_accuracy: 0.7700 - val_auc: 0.8713 - val_loss: 0.4695 - learning_rate: 1.0000e-04
# Epoch 8/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1349s 617ms/step - accuracy: 0.7804 - auc: 0.8630 - loss: 0.4595 - val_accuracy: 0.7595 - val_auc: 0.8697 - val_loss: 0.4937 - learning_rate: 1.0000e-04
# Epoch 9/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1352s 618ms/step - accuracy: 0.7804 - auc: 0.8640 - loss: 0.4573 - val_accuracy: 0.7491 - val_auc: 0.8756 - val_loss: 0.4923 - learning_rate: 1.0000e-04
# Epoch 10/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1375s 628ms/step - accuracy: 0.7828 - auc: 0.8667 - loss: 0.4525 - val_accuracy: 0.7740 - val_auc: 0.8743 - val_loss: 0.4632 - learning_rate: 1.0000e-04
# Epoch 11/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1380s 631ms/step - accuracy: 0.7816 - auc: 0.8665 - loss: 0.4532 - val_accuracy: 0.7661 - val_auc: 0.8746 - val_loss: 0.4714 - learning_rate: 1.0000e-04
# Epoch 12/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1453s 664ms/step - accuracy: 0.7838 - auc: 0.8687 - loss: 0.4500 - val_accuracy: 0.7781 - val_auc: 0.8773 - val_loss: 0.4636 - learning_rate: 1.0000e-04
# Epoch 13/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1433s 655ms/step - accuracy: 0.7828 - auc: 0.8686 - loss: 0.4491 - val_accuracy: 0.7758 - val_auc: 0.8756 - val_loss: 0.4638 - learning_rate: 1.0000e-04
# Epoch 14/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1395s 638ms/step - accuracy: 0.7857 - auc: 0.8698 - loss: 0.4487 - val_accuracy: 0.7546 - val_auc: 0.8764 - val_loss: 0.4864 - learning_rate: 1.0000e-04
# Epoch 15/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1380s 631ms/step - accuracy: 0.7845 - auc: 0.8695 - loss: 0.4484 - val_accuracy: 0.7554 - val_auc: 0.8754 - val_loss: 0.4911 - learning_rate: 1.0000e-04
# Epoch 16/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1419s 638ms/step - accuracy: 0.7892 - auc: 0.8736 - loss: 0.4418 - val_accuracy: 0.7655 - val_auc: 0.8779 - val_loss: 0.4775 - learning_rate: 5.0000e-05
# Epoch 17/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1381s 629ms/step - accuracy: 0.7879 - auc: 0.8732 - loss: 0.4422 - val_accuracy: 0.7703 - val_auc: 0.8786 - val_loss: 0.4648 - learning_rate: 5.0000e-05
# Epoch 18/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1377s 629ms/step - accuracy: 0.7873 - auc: 0.8747 - loss: 0.4393 - val_accuracy: 0.7548 - val_auc: 0.8777 - val_loss: 0.4966 - learning_rate: 5.0000e-05
# Epoch 19/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1380s 631ms/step - accuracy: 0.7894 - auc: 0.8747 - loss: 0.4399 - val_accuracy: 0.7608 - val_auc: 0.8785 - val_loss: 0.4876 - learning_rate: 5.0000e-05
# Epoch 20/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1399s 639ms/step - accuracy: 0.7904 - auc: 0.8752 - loss: 0.4394 - val_accuracy: 0.7629 - val_auc: 0.8783 - val_loss: 0.4837 - learning_rate: 5.0000e-05
# Epoch 21/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1379s 630ms/step - accuracy: 0.7914 - auc: 0.8775 - loss: 0.4360 - val_accuracy: 0.7639 - val_auc: 0.8795 - val_loss: 0.4825 - learning_rate: 2.5000e-05
# Epoch 22/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1374s 628ms/step - accuracy: 0.7925 - auc: 0.8762 - loss: 0.4377 - val_accuracy: 0.7624 - val_auc: 0.8796 - val_loss: 0.4856 - learning_rate: 2.5000e-05
# Epoch 23/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1396s 638ms/step - accuracy: 0.7929 - auc: 0.8767 - loss: 0.4368 - val_accuracy: 0.7669 - val_auc: 0.8796 - val_loss: 0.4788 - learning_rate: 2.5000e-05
# Epoch 24/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1376s 629ms/step - accuracy: 0.7913 - auc: 0.8769 - loss: 0.4361 - val_accuracy: 0.7660 - val_auc: 0.8782 - val_loss: 0.4803 - learning_rate: 2.5000e-05
# Epoch 25/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1660s 759ms/step - accuracy: 0.7959 - auc: 0.8804 - loss: 0.4319 - val_accuracy: 0.7570 - val_auc: 0.8785 - val_loss: 0.4925 - learning_rate: 1.2500e-05
# Epoch 26/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1852s 846ms/step - accuracy: 0.7914 - auc: 0.8766 - loss: 0.4373 - val_accuracy: 0.7557 - val_auc: 0.8790 - val_loss: 0.4910 - learning_rate: 1.2500e-05
# Epoch 27/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1346s 601ms/step - accuracy: 0.7930 - auc: 0.8782 - loss: 0.4344 - val_accuracy: 0.7575 - val_auc: 0.8787 - val_loss: 0.4894 - learning_rate: 1.2500e-05
# Epoch 28/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1285s 587ms/step - accuracy: 0.7921 - auc: 0.8784 - loss: 0.4348 - val_accuracy: 0.7499 - val_auc: 0.8780 - val_loss: 0.4995 - learning_rate: 6.2500e-06
# Epoch 29/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1288s 589ms/step - accuracy: 0.7934 - auc: 0.8794 - loss: 0.4325 - val_accuracy: 0.7524 - val_auc: 0.8784 - val_loss: 0.4932 - learning_rate: 6.2500e-06
# Epoch 30/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1286s 588ms/step - accuracy: 0.7961 - auc: 0.8790 - loss: 0.4337 - val_accuracy: 0.7559 - val_auc: 0.8788 - val_loss: 0.4917 - learning_rate: 6.2500e-06
# Epoch 31/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1393s 611ms/step - accuracy: 0.7935 - auc: 0.8774 - loss: 0.4360 - val_accuracy: 0.7531 - val_auc: 0.8790 - val_loss: 0.4955 - learning_rate: 3.1250e-06
# Epoch 32/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1522s 696ms/step - accuracy: 0.7923 - auc: 0.8770 - loss: 0.4362 - val_accuracy: 0.7558 - val_auc: 0.8790 - val_loss: 0.4897 - learning_rate: 3.1250e-06
# Epoch 33/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1489s 680ms/step - accuracy: 0.7945 - auc: 0.8792 - loss: 0.4322 - val_accuracy: 0.7535 - val_auc: 0.8791 - val_loss: 0.4937 - learning_rate: 3.1250e-06
# Epoch 34/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1455s 665ms/step - accuracy: 0.7942 - auc: 0.8794 - loss: 0.4335 - val_accuracy: 0.7519 - val_auc: 0.8791 - val_loss: 0.4960 - learning_rate: 1.5625e-06
# Epoch 35/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1360s 621ms/step - accuracy: 0.7931 - auc: 0.8781 - loss: 0.4344 - val_accuracy: 0.7528 - val_auc: 0.8792 - val_loss: 0.4954 - learning_rate: 1.5625e-06
# Epoch 36/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1299s 593ms/step - accuracy: 0.7931 - auc: 0.8782 - loss: 0.4342 - val_accuracy: 0.7543 - val_auc: 0.8788 - val_loss: 0.4920 - learning_rate: 1.5625e-06
# Epoch 37/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1300s 594ms/step - accuracy: 0.7956 - auc: 0.8801 - loss: 0.4313 - val_accuracy: 0.7515 - val_auc: 0.8788 - val_loss: 0.4983 - learning_rate: 1.0000e-06
# Epoch 38/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1327s 606ms/step - accuracy: 0.7946 - auc: 0.8805 - loss: 0.4302 - val_accuracy: 0.7515 - val_auc: 0.8789 - val_loss: 0.4985 - learning_rate: 1.0000e-06
# Epoch 39/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1337s 611ms/step - accuracy: 0.7936 - auc: 0.8785 - loss: 0.4344 - val_accuracy: 0.7519 - val_auc: 0.8788 - val_loss: 0.4980 - learning_rate: 1.0000e-06
# Epoch 40/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1314s 601ms/step - accuracy: 0.7937 - auc: 0.8791 - loss: 0.4323 - val_accuracy: 0.7516 - val_auc: 0.8788 - val_loss: 0.4974 - learning_rate: 1.0000e-06
# Epoch 41/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1728s 790ms/step - accuracy: 0.7941 - auc: 0.8803 - loss: 0.4309 - val_accuracy: 0.7516 - val_auc: 0.8789 - val_loss: 0.4969 - learning_rate: 1.0000e-06
# Epoch 42/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1310s 599ms/step - accuracy: 0.7941 - auc: 0.8795 - loss: 0.4334 - val_accuracy: 0.7514 - val_auc: 0.8788 - val_loss: 0.4981 - learning_rate: 1.0000e-06
# Epoch 43/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1339s 597ms/step - accuracy: 0.7934 - auc: 0.8794 - loss: 0.4323 - val_accuracy: 0.7518 - val_auc: 0.8790 - val_loss: 0.4961 - learning_rate: 1.0000e-06
# Epoch 44/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1315s 601ms/step - accuracy: 0.7917 - auc: 0.8771 - loss: 0.4356 - val_accuracy: 0.7522 - val_auc: 0.8790 - val_loss: 0.4965 - learning_rate: 1.0000e-06
# Epoch 45/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1302s 595ms/step - accuracy: 0.7925 - auc: 0.8789 - loss: 0.4328 - val_accuracy: 0.7524 - val_auc: 0.8790 - val_loss: 0.4965 - learning_rate: 1.0000e-06
# Epoch 46/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1306s 597ms/step - accuracy: 0.7930 - auc: 0.8783 - loss: 0.4350 - val_accuracy: 0.7509 - val_auc: 0.8789 - val_loss: 0.4988 - learning_rate: 1.0000e-06
# Epoch 47/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1306s 597ms/step - accuracy: 0.7948 - auc: 0.8790 - loss: 0.4338 - val_accuracy: 0.7516 - val_auc: 0.8791 - val_loss: 0.4988 - learning_rate: 1.0000e-06
# Epoch 48/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1299s 594ms/step - accuracy: 0.7925 - auc: 0.8795 - loss: 0.4315 - val_accuracy: 0.7520 - val_auc: 0.8792 - val_loss: 0.4965 - learning_rate: 1.0000e-06
# Epoch 49/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 2157s 986ms/step - accuracy: 0.7907 - auc: 0.8789 - loss: 0.4324 - val_accuracy: 0.7519 - val_auc: 0.8792 - val_loss: 0.4975 - learning_rate: 1.0000e-06
# Epoch 50/50
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 2063s 931ms/step - accuracy: 0.7964 - auc: 0.8802 - loss: 0.4318 - val_accuracy: 0.7514 - val_auc: 0.8792 - val_loss: 0.4993 - learning_rate: 1.0000e-06

# %%
def plot_history(history):
    plt.figure(figsize=(12, 6))
    
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Val Accuracy')
    plt.title('CNN+LSTM Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)
    
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title('CNN+LSTM Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.show()

# %%
plot_history(history)

# %%
model.save('model2.keras')
